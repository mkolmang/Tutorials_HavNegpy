# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
os.chdir(r'C:\Users\mkolmang\Desktop\Desktop\MD_scripts\compress')
# %matplotlib inline

# %%
filename = 'nvt_new.log'
col_names = ['timestep','PE']
df = pd.read_csv(filename, sep='\t',index_col=False,usecols = [0,1],names=col_names,header=None,skiprows=1,encoding='unicode_escape',engine='python')
x = df['timestep']
y = df['PE']
plt.plot(x,y,color='k')
plt.title('NVT log')
# Out:
# Text(0.5, 1.0, 'NVT log')

# %%
filename = 'npt.log'
col_names = ['timestep','PE']
df = pd.read_csv(filename, sep='\t',index_col=False,usecols = [0,1],names=col_names,header=None,skiprows=1,encoding='unicode_escape',engine='python')
x = df['timestep']
y = df['PE']
plt.plot(x,y,color='k')
plt.title('NPT log')
# Out:
# Text(0.5, 1.0, 'NPT log')

# %%
print(x,y)
# Out:
# 0      3000000
# 1      3005000
# 2      3010000
# 3      3015000
# 4      3020000
#         ...
# 195    3975000
# 196    3980000
# 197    3985000
# 198    3990000
# 199    3995000
# Name: timestep, Length: 200, dtype: int64 0     -37084.894530
# 1      18540.683590
# 2      14738.466800
# 3       -889.271484
# 4       3879.792969
#            ...
# 195   -49208.414060
# 196   -49739.031250
# 197   -50504.214840
# 198   -50026.500000
# 199   -51617.324220
# Name: PE, Length: 200, dtype: float64
